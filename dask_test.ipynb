# %%
import numpy as np
import pandas as pd
import dask.dataframe as dd

# %%
track_features = dd.read_csv("data/mini_data/data/track_features/tf_mini.csv")
training_set = dd.read_csv("data/mini_data/data/training_set/log_mini.csv")

# %%
track_features
# Out:
# Dask DataFrame Structure:
#               track_id duration release_year us_popularity_estimate acousticness beat_strength bounciness danceability dyn_range_mean   energy flatness instrumentalness    key liveness loudness mechanism    mode organism speechiness    tempo time_signature  valence acoustic_vector_0 acoustic_vector_1 acoustic_vector_2 acoustic_vector_3 acoustic_vector_4 acoustic_vector_5 acoustic_vector_6 acoustic_vector_7
# npartitions=1
#                 object  float64        int64                float64      float64       float64    float64      float64        float64  float64  float64          float64  int64  float64  float64   float64  object  float64     float64  float64          int64  float64           float64           float64           float64           float64           float64           float64           float64           float64
# ...

# %%
track_features.describe().compute()
# Out:
#            duration  release_year  us_popularity_estimate  acousticness  \
# count  50704.000000  50704.000000            50704.000000  50704.000000
# mean     222.267980   2010.324748               99.455131      0.250336
# std       72.224839     11.471866                1.139222      0.276047
# min       30.013330   1950.000000               90.018900      0.000000
# 25%      183.933334   2009.000000               99.509670      0.025291
# 50%      214.866669   2015.000000               99.865444      0.135821
# 75%      250.426666   2017.000000               99.961131      0.406142
# max     1787.760986   2018.000000               99.999997      0.995796
#
#        beat_strength    bounciness  danceability  dyn_range_mean  \
# count   50704.000000  50704.000000  50704.000000    50704.000000
# mean        0.492075      0.514526      0.611742        8.215950
# std         0.158102      0.182595      0.166146        2.410626
# ...

# %%
track_features.columns
# Out:
# Index(['track_id', 'duration', 'release_year', 'us_popularity_estimate',
#        'acousticness', 'beat_strength', 'bounciness', 'danceability',
#        'dyn_range_mean', 'energy', 'flatness', 'instrumentalness', 'key',
#        'liveness', 'loudness', 'mechanism', 'mode', 'organism', 'speechiness',
#        'tempo', 'time_signature', 'valence', 'acoustic_vector_0',
#        'acoustic_vector_1', 'acoustic_vector_2', 'acoustic_vector_3',
#        'acoustic_vector_4', 'acoustic_vector_5', 'acoustic_vector_6',
#        'acoustic_vector_7'],
#       dtype='object')

# %%
import dask
import xgboost
import dask_xgboost
